# %% [markdown]
# Variavel Instrumental ou Regressao em dois estagios (2 stage least square square)
#
# - Gujarati pg 661

# %% [markdown]
# # Oferta e Demanda

# %% [markdown]
# ## Forma estrutural
# - https://www.youtube.com/watch?v=mzJAxoBfM60

# %% [markdown]
# ![image-3.png](attachment:image-3.png)
# - Q: Quantidade
# - P: Preço
# - Y: Renda
# - M: Materia Prima
# - S: Salario

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - https://www.youtube.com/watch?v=LwhBwe6jnKw

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - https://www.youtube.com/watch?v=2ttHMvIVRQc
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# - Y: variaveis endogenas
# - X: Variaveis exogenas

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Relação entre os coeficientes estruturais e reduzidos em modelos de oferta e demanda.
# - https://drive.google.com/file/d/1ajroujSP7pE0J2wWIxj5cvW6bBJ31Zwy/view
#
# MEtodo conhecido como **mínimos quadrados indiretos (MQI)**.
