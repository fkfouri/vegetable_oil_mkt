# %% [markdown]
# #
#
# ![image.png](attachment:image.png)
#
# Parecido com o Viral. Esta na pasta outros.
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Stock Market Trend Prediction Using Hidden Markov Model
# - https://www.intechopen.com/chapters/74027
#
# ![image.png](attachment:image.png)
