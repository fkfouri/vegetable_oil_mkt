# %% [markdown]
# MATH Symbols
#
# - https://kapeli.com/cheat_sheets/LaTeX_Math_Symbols.docset/Contents/Resources/Documents/index
# - https://rpruim.github.io/s341/S19/from-class/MathinRmd.html

# %% [markdown]
# $\overrightarrow{AB}$
#
# $\prec\preceq\simeq$
#
# $\succ\succeq\approx$

# %% [markdown]
# $ x \succeq y$: x é ao menos tão bom quanto y

# %% [markdown]
# $x \succ y$: x é estritamente prefivel a y

# %% [markdown]
# $\sim$ Refalção de indiferença

# %% [markdown]
# $\Leftrightarrow$ se, e somenete se
#
# ![image.png](attachment:image.png) Pg25 Fiani
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png) pg48

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $\pi_i(s_i^*, s_{-i}) > \pi(s^{**}_i,s_{-i}) $ para todos $s_{-i}$
#
# pg83
