# %% [markdown]
# # BELLMAN

# %% [markdown]
# |image|ref|
# |:--|-:-|
# |![image.png](attachment:image.png)|[ref](https://python-advanced.quantecon.org/dyn_stack.html#equation-bellman-stack)
# |![image-2.png](attachment:image-2.png)|[ref](https://python.quantecon.org/markov_perf.html#equation-game4)

# %% [markdown]
# - $\beta$: é um fator entre 0 e 1  de desconto de tempo

# %% [markdown]
# |image|ref|
# |:--|-:-|
# |![image.png](attachment:image.png)|[ref](https://www.youtube.com/watch?v=cOy0sUTouyo)
#
# - S: Estado
# - a: ação
# - R: Recompensa
# - $\gamma$: Desconto
# - $V(s)$: Qual o valor para estar em um determinado estado
# - $R(s,a)$: tomando uma ação $a$, vou para um estados $s$ e vou ganhar uma recompensa $R$. A recompensa por chegar no bloco.
# - $(max)_a$: Significa uma ação que chega ao maior valor
# - $\gamma V(s')$: Valor de estado seguinte (s') multiplicao pelo fator de desconto
#
#
# ![image-2.png](attachment:image-2.png)
#
# Lembrando que a maior recompensa é chegar no verde. E a menor recompensa é chegar no vermelho.
#
# ![image-4.png](attachment:image-4.png)
#
# Realizando o calculo recursivo até encontrar todos os valores. Assumindo $\gamma$ como 0.9.
#
# ![image-5.png](attachment:image-5.png)
#
# Quanto mais longe menor é o valor

# %% [markdown]
# ![image.png](https://miro.medium.com/max/968/1*NoV4y5BxjGs5PZD3gZzgpw.gif)
# [ref](https://towardsdatascience.com/markov-decision-processes-and-bellman-equations-45234cce9d25)
